# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Индексы полезны при работе со строками. Пользователи используют платёжную информацию в нашем приложении, и иногда данные приходят с лишним пробелом в конце. Длина номера карты может быть разной.
#
# ## Ваша задача:
#
# - Уберите пробелы в конце строки (если они есть).
# - Замените последние 4 символа строки на *.
# - Сохраните результат в переменную masked_card.

# %%
card_number = "123456789012345 "
masked_card = card_number.strip()[:-4] + "****"
print(masked_card)
# Out:
# 12345678901****

# %% [markdown]
# ## Аналитики часто сталкиваются с задачами преобразования телефонных номеров — например, чтобы привести их к единому международному формату для выгрузки или отчётов.В этой задаче вы потренируетесь изменять формат номера.
#
# ### Телефон пользователя хранится в переменной phone в формате целого числа.
#
# #### Ваша задача:
#
# - Преобразуйте число в строку.
# - Замените первую цифру 8 на +7.
# - Сохраните результат в переменную formatted_phone.

# %%
phone = 81112223344
str_phone = str(phone)

formatted_phone = "+7" + str_phone[1:]

print(formatted_phone)
# Out:
# +71112223344

# %% [markdown]
# ## Идентификатор товара сохранён в строке в формате: <код города>-<id товара>-<категория>
#
# ### Ваша задача:
#
# #### Создайте три переменные:
#
# - city_code — строка с первой буквой в верхнем регистре (например, "msk" → "Msk").
# - item_id — целое число.
# - category — строка без изменений.

# %%
# Пример входных данных
product_info = "msk-245-electronics"


city_code = product_info.split("-")[0].capitalize()

item_id = int(product_info.split("-")[1])

category = product_info.split("-")[2]  
print(city_code)
print(item_id)
# Out:
# Msk
# 255

# %% [markdown]
# # Хотим найти позицию, на которой упоминается промокод в рекламной рассылке. В переменной promo сохранён промокод. В переменной email_text хранится текст письма.
#
# ## Ваша задача:
#
# ### Найдите индекс, на котором начинается промокод в тексте (учитывая, что регистр букв может отличаться).
#
# - Если промокод не найден, индекс должен быть равен -1.
# - Сохраните результат в переменную promo_index.
# - Подсказка: Мы пока не проходили условия (if). Вспомните, какой метод строк возвращает -1, если подстрока не найдена.

# %%
promo = "SAVE20"
email_text = "Добрый день! Используйте промокод save20 для скидки."

email_text = email_text.lower()
promo_index = email_text.find(promo.lower())


print(email_text)
print(promo_index)
# Out:
# добрый день! используйте промокод save20 для скидки.
# 34

# %% [markdown]
# ## В этой задаче вы потренируетесь находить нужные элементы в строке и сравнивать их. В переменной user_email хранится e-mail пользователя.
#
# ### Ваша задача:
#
# #### Проверьте, принадлежит ли e-mail клиенту karpovmarket. Адрес должен содержать ровно karpovmarket. сразу после символа @, а домен (например, .ru, .kz) может быть любым.
#
# - Если это так, сохраните True в переменную is_karpov_client.
#
# - Если e-mail не соответствует этому правилу или похож только частично (например, bestkarpovmarket), сохраните False.

# %%
# Пример 1
user_email = 'ivanov@karpovmarket.ru'
# Ожидаемый результат: True
# Пояснение: после @ стоит ровно "karpovmarket."

is_karpov_client = user_email.split("@")[1].split(".")[0] == "karpovmarket"
print(is_karpov_client)
# Out:
# True

# %% [markdown]
# ## Аналитики и специалисты по продуктам часто формируют удобные текстовые отчёты или сообщения о заказах для пользователей или служб поддержки.В этой задаче вы потренируетесь объединять списки и вычислять итоговую стоимость.
#
# ### У вас есть три переменные:
#
# - items — список товаров в корзине клиента (строки).
# - prices — список чисел с ценами этих товаров.
# - user_id — целое число (id пользователя).
# - Ваша задача: Сформируйте строку, в которой:
#
# - Все товары перечислены через запятую.
# - Указан id пользователя.
# - Добавлена финальная сумма заказа.
# - Сохраните эту строку в переменную summary.
#
# - Формат итоговой строки можно посмотреть в примере ниже.

# %%
# Пример входных данных
items = ["ноутбук", "мышь", "клавиатура"]
prices = [50000, 1500, 3000]
user_id = 42

join_list = ", ".join(items)
print(test)


summary = f"Заказ пользователя {user_id}: {', '.join(items)}. Сумма заказа: {sum(prices)}"
print(summary)

# Ожидаемый результат
#summary = "Заказ пользователя 42: ноутбук, мышь, клавиатура. Сумма заказа: 54500"
# Out:
# ноутбук, мышь, клавиатура
# Заказ пользователя 42: ноутбук, мышь, клавиатура. Сумма заказа: 54500

# %% [markdown]
# ### Форматирование отчётов — важный навык аналитика. В этой задаче вы научитесь красиво оформлять текстовые отчёты с числами и процентами.
#
# #### У вас есть:
#
# - revenues — список целых чисел с выручкой по дням за неделю.
# - plan — целое число, сумма запланированной выручки за неделю.
# - Ваша задача:Сформировать строку report следующего вида:
#
# - Общая выручка за неделю {сумма с разделителем тысяч запятыми}. План выполнен на {процент}%

# %%
revenues = [120000, 150000, 130000, 170000, 160000, 140000, 180000]
plan = 900000


report = f"Общая выручка за неделю {sum(revenues):,}. План выполнен на {round(sum(revenues)/plan * 100, 1)}%"
# Ожидаемый результат
#report = "Общая выручка за неделю 1,050,000. План выполнен на 116.7%"
